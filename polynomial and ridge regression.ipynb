# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("simple_swat_weather.csv")
data
# Out:
#     Day  Temperature_C  Humidity_Percent  Rainfall_mm
# 0     1             14                65            2
# 1     2             16                63            0
# 2     3             18                60            0
# 3     4             21                58            0
# 4     5             24                55            0
# 5     6             27                50            0
# 6     7             30                45            0
# 7     8             32                40            0
# 8     9             34                38            0
# 9    10             35                35            0
# 10   11             34                37            0
# 11   12             32                40            1
# 12   13             30                45            3
# 13   14             28                50            6
# 14   15             25                55           10

# %%
data.head()
# Out:
#    Day  Temperature_C  Humidity_Percent  Rainfall_mm
# 0    1             14                65            2
# 1    2             16                63            0
# 2    3             18                60            0
# 3    4             21                58            0
# 4    5             24                55            0

# %%
X = data[['Day']].values
y = data['Temperature_C'].values

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=3)   
X_poly = poly.fit_transform(X)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_poly)

# %%
plt.scatter(X, y, color='blue', label="Actual Data")
plt.plot(X, y_pred, color='red', label="Polynomial Curve")

plt.xlabel("Day")
plt.ylabel("Temperature")
plt.title("Polynomial Regression - Swat Weather")

plt.legend()
plt.show()

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha=1.0)  
ridge_model.fit(X_poly, y)
# Out:
# Ridge()

# %%
y_pred_ridge = ridge_model.predict(X_poly)

# %%
plt.scatter(X, y, color='blue', label="Actual Data")

# Polynomial
plt.plot(X, y_pred, color='red', label="Polynomial")

# Ridge
plt.plot(X, y_pred_ridge, color='green', label="Ridge Regression")

plt.xlabel("Day")
plt.ylabel("Temperature")
plt.title("Polynomial vs Ridge Regression")

plt.legend()
plt.show()
